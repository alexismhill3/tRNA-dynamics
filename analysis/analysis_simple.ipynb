# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import seaborn as sns
from simulation.single_codon import single_codon
from matplotlib import rcParams
# %matplotlib inline

# %%
def read_sim(path_pref, seed_start=1, seed_end=3, seed_incr=1):
    df_master = pd.read_csv(f"{path_pref}_{seed_start}.tsv", sep="\t")
    df_master["seed"] = str(seed_start)
    for i in range(seed_start+1, seed_end+1):
        tmp = pd.read_csv(f"{path_pref}_{i}.tsv", sep="\t")
        tmp["seed"] = str(i)
        df_master = df_master.append(tmp, ignore_index=True)
    return df_master

# %%
# read in sim runs and concatenate
df_master = pd.read_csv(f"../output/sim/single_gene_single_codon_{1}.tsv", sep="\t")
df_master["seed"] = "1"
for i in range(2, 4):
    tmp = pd.read_csv(f"../output/sim/single_gene_single_codon_{i}.tsv", sep="\t")
    tmp["seed"] = f"{i}"
    df_master = df_master.append(tmp, ignore_index=True)
display(df_master)
# Out:
#              time         species  protein  transcript  ribo_density seed
# 0        0.000000     CAT_charged     10.0         0.0      0.000000    1
# 1        0.000000   CAT_uncharged      0.0         0.0      0.000000    1
# 2        0.000000     TTT_charged    200.0         0.0      0.000000    1
# 3        0.000000   TTT_uncharged      0.0         0.0      0.000000    1
# 4        0.000000  __proteinX_rbs      0.0         0.0      0.000000    1
# ...           ...             ...      ...         ...           ...  ...
# 6499  1199.999065  __proteinX_rbs   1883.0         0.0      0.000000    3
# 6500  1199.999065      __ribosome      4.0         0.0      0.000000    3
# 6501  1199.999065            phi1      2.0         0.0      0.000000    3
# 6502  1199.999065        proteinX  21622.0      1893.0      0.103539    3
# 6503  1199.999065          rnapol     19.0         0.0      0.000000    3
#
# [6504 rows x 6 columns]

# %%
df_filtered = df_master[(df_master.species == "TTT_charged") | (df_master.species == "TTT_uncharged")]
df_filtered
# Out:
#              time        species  protein  transcript  ribo_density seed
# 2        0.000000    TTT_charged    200.0         0.0           0.0    1
# 3        0.000000  TTT_uncharged      0.0         0.0           0.0    1
# 10       4.999525    TTT_charged    155.0         0.0           0.0    1
# 11       4.999525  TTT_uncharged     45.0         0.0           0.0    1
# 19      10.001277    TTT_charged    155.0         0.0           0.0    1
# ...           ...            ...      ...         ...           ...  ...
# 6480  1189.999098  TTT_uncharged    198.0         0.0           0.0    3
# 6488  1194.999719    TTT_charged      3.0         0.0           0.0    3
# 6489  1194.999719  TTT_uncharged    197.0         0.0           0.0    3
# 6497  1199.999065    TTT_charged      2.0         0.0           0.0    3
# 6498  1199.999065  TTT_uncharged    198.0         0.0           0.0    3
#
# [1446 rows x 6 columns]

# %%
rcParams['figure.figsize'] = [10, 5]
sns.lineplot(x="time", y="protein", units="seed", hue="species", estimator=None, data=df_filtered)
# Out:
# <AxesSubplot:xlabel='time', ylabel='protein'>

# %%
#for i in range(1,4):
#    single_codon(i, 1e2, 1200, "/home/alexis/projects/tRNA-dynamics/output/sim")

# %%
df_master = pd.read_csv(f"../output/sim/single_gene_single_codon_100.0_{1}.tsv", sep="\t")
df_master["seed"] = "1"
for i in range(2, 4):
    tmp = pd.read_csv(f"../output/sim/single_gene_single_codon_100.0_{i}.tsv", sep="\t")
    tmp["seed"] = f"{i}"
    df_master = df_master.append(tmp, ignore_index=True)
display(df_master)
# Out:
#              time         species   protein  transcript  ribo_density seed
# 0        0.000000     TTT_charged     200.0         0.0      0.000000    1
# 1        0.000000   TTT_uncharged       0.0         0.0      0.000000    1
# 2        0.000000  __proteinX_rbs       0.0         0.0      0.000000    1
# 3        0.000000      __ribosome     200.0         0.0      0.000000    1
# 4        0.000000            phi1       2.0         0.0      0.000000    1
# ...           ...             ...       ...         ...           ...  ...
# 5053  1199.999026  __proteinX_rbs    1927.0         0.0      0.000000    3
# 5054  1199.999026      __ribosome      46.0         0.0      0.000000    3
# 5055  1199.999026            phi1       2.0         0.0      0.000000    3
# 5056  1199.999026        proteinX  154250.0      1940.0      0.079381    3
# 5057  1199.999026          rnapol      20.0         0.0      0.000000    3
#
# [5058 rows x 6 columns]

# %%
df_master_1 = read_sim("../output/sim/single_gene_single_codon_100.0")

# %%
display(df_master_1)
# Out:
#              time         species   protein  transcript  ribo_density seed
# 0        0.000000     TTT_charged     200.0         0.0      0.000000    1
# 1        0.000000   TTT_uncharged       0.0         0.0      0.000000    1
# 2        0.000000  __proteinX_rbs       0.0         0.0      0.000000    1
# 3        0.000000      __ribosome     200.0         0.0      0.000000    1
# 4        0.000000            phi1       2.0         0.0      0.000000    1
# ...           ...             ...       ...         ...           ...  ...
# 5053  1199.999026  __proteinX_rbs    1927.0         0.0      0.000000    3
# 5054  1199.999026      __ribosome      46.0         0.0      0.000000    3
# 5055  1199.999026            phi1       2.0         0.0      0.000000    3
# 5056  1199.999026        proteinX  154250.0      1940.0      0.079381    3
# 5057  1199.999026          rnapol      20.0         0.0      0.000000    3
#
# [5058 rows x 6 columns]

# %%
df_filtered = df_master[(df_master.species == "TTT_charged") | (df_master.species == "TTT_uncharged")]
df_filtered
# Out:
#              time        species  protein  transcript  ribo_density seed
# 0        0.000000    TTT_charged    200.0         0.0           0.0    1
# 1        0.000000  TTT_uncharged      0.0         0.0           0.0    1
# 6        4.999313    TTT_charged    200.0         0.0           0.0    1
# 7        4.999313  TTT_uncharged      0.0         0.0           0.0    1
# 13       9.999571    TTT_charged    190.0         0.0           0.0    1
# ...           ...            ...      ...         ...           ...  ...
# 5038  1189.999007  TTT_uncharged    159.0         0.0           0.0    3
# 5044  1194.999003    TTT_charged     29.0         0.0           0.0    3
# 5045  1194.999003  TTT_uncharged    171.0         0.0           0.0    3
# 5051  1199.999026    TTT_charged     31.0         0.0           0.0    3
# 5052  1199.999026  TTT_uncharged    169.0         0.0           0.0    3
#
# [1446 rows x 6 columns]

# %%
rcParams['figure.figsize'] = [10, 5]
sns.lineplot(x="time", y="protein", units="seed", hue="species", estimator=None, data=df_filtered)
# Out:
# <AxesSubplot:xlabel='time', ylabel='protein'>
